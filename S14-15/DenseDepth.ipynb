# %% [markdown]
# <a href="https://colab.research.google.com/github/sobti/TSAI/blob/master/S14-15/DenseDepth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive
drive.mount('/content/gdrive/')
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/resnet/YoloV3\DenseDepth')
os.chdir('/content/gdrive/My Drive/Colab Notebooks/resnet/YoloV3/DenseDepth')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
#!git clone https://github.com/ialhashim/DenseDepth.git

# %%
#!wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5

# %%
import cv2
path_to_file='output/sk2.png'
if not os.path.exists(path_to_file):
   print('File not found')

img = cv2.imread(path_to_file)
print(img.shape)
resized = cv2.resize(img,(640,480),interpolation = cv2.INTER_AREA)
print(resized.shape)
filename='sk2.png'
cv2.imwrite('output/'+filename,resized)
# Out:
# (224, 224, 3)
# (480, 640, 3)
# True

# %%
# %matplotlib inline

# %%
# !python test.py

# %% [markdown]
# (480, 640, 3)-input

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('test.png') )

# %%
import cv2
from google.colab.patches import cv2_imshow
ig = cv2.imread('output1/img0.png')
cv2_imshow(ig)
ig.shape
# Out:
# <PIL.Image.Image image mode=RGB size=112x112 at 0x7EFF043D3A20>
# (112, 112, 3)
