# %% [markdown]
# <a href="https://colab.research.google.com/github/sobti/TSAI/blob/master/Yolov5/Yolov5_custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive
drive.mount('/content/gdrive/')
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')
os.chdir('/content/gdrive/My Drive/Colab Notebooks')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt  # install dependencies
# Out:
# Requirement already up-to-date: numpy==1.17 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 2)) (1.17.0)
# Requirement already up-to-date: opencv-python in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 3)) (4.2.0.34)
# Requirement already up-to-date: torch>=1.5 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 4)) (1.5.0+cu101)
# Requirement already up-to-date: matplotlib in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 5)) (3.2.1)
# Requirement already up-to-date: pycocotools in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 6)) (2.0.0)
# Requirement already up-to-date: tqdm in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 7)) (4.46.1)
# Requirement already up-to-date: pillow in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 8)) (7.1.2)
# ...

# %%
import torch
from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.0+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
! python yolov5/train.py --img 640 --batch 16 --epochs 300 --data ./yolov5/data/custom128.yaml --cfg ./yolov5/models/yolov5s.yaml --weights './yolov5/weights/yolov5s.pt'
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# {'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.58, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.014, 'hsv_s': 0.68, 'hsv_v': 0.36, 'degrees': 0.0, 'translate': 0.0, 'scale': 0.5, 'shear': 0.0}
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='././yolov5/models/yolov5s.yaml', data='././yolov5/data/custom128.yaml', device='', epochs=300, evolve=False, img_size=[640], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='./yolov5/weights/yolov5s.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-06-13 09:11:08.294195: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python yolov5/detect.py --weights weights/last.pt --img 416 --conf 0.4 --source ./inference/images/
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (3342/8338) inference/images/spongebob.mp4: 224x416 Done. (0.009s)
# video 1/1 (3343/8338) inference/images/spongebob.mp4: 224x416 Done. (0.007s)
# video 1/1 (3344/8338) inference/images/spongebob.mp4: 224x416 Done. (0.007s)
# video 1/1 (3345/8338) inference/images/spongebob.mp4: 224x416 Done. (0.008s)
# video 1/1 (3346/8338) inference/images/spongebob.mp4: 224x416 Done. (0.007s)
# video 1/1 (3347/8338) inference/images/spongebob.mp4: 224x416 Done. (0.007s)
# video 1/1 (3348/8338) inference/images/spongebob.mp4: 224x416 Done. (0.007s)
# video 1/1 (3349/8338) inference/images/spongebob.mp4: 224x416 Done. (0.007s)
# video 1/1 (3350/8338) inference/images/spongebob.mp4: 224x416 Done. (0.009s)
# video 1/1 (3351/8338) inference/images/spongebob.mp4: 224x416 Done. (0.007s)
# video 1/1 (3352/8338) inference/images/spongebob.mp4: 224x416 Done. (0.007s)
# ...
